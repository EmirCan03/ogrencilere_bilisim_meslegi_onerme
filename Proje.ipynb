# %% [markdown]
# <a href="https://colab.research.google.com/github/EmirCan03/ogrencilere_bilisim_meslegi_onerme/blob/main/Proje.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-cb442cde-32ed-4a17-a86b-4bbe04bbbaef" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cb442cde-32ed-4a17-a86b-4bbe04bbbaef">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import io

# %%
data = pd.read_excel('/content/Student Placement.xlsx')

# %%
data
# Out:
#      DSA  DBMS  OS  CN  Mathmetics  Aptitute  Comm  Problem Solving  Creative  \
# 0     49    22  41  26           7        28    61                1         8
# 1     39    46  45  47           3        35    65                4        10
# 2     28    32  45  35          10        23    85                3        10
# 3     52    38  33  38          19        27    62                1         9
# 4     23    31  30  38          10        13    72                4         8
# ..   ...   ...  ..  ..         ...       ...   ...              ...       ...
# 702   17    32  18  11           7        40    60                2         6
# 703    7    22  25  33           8        29    71                3         5
# 704   35     5  13  20          17        45    55                3         5
# 705   16    28   6   7          18        33    67                3         4
# 706   18    12  10  28          22        31    55                5         3
#
# ...

# %%
df = pd.DataFrame(data)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 707 entries, 0 to 706
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   DSA              707 non-null    int64
#  1   DBMS             707 non-null    int64
#  2   OS               707 non-null    int64
#  3   CN               707 non-null    int64
#  4   Mathmetics       707 non-null    int64
#  5   Aptitute         707 non-null    int64
#  6   Comm             707 non-null    int64
#  7   Problem Solving  707 non-null    int64
#  8   Creative         707 non-null    int64
#  9   Hackathons       707 non-null    int64
#  10  Skill            707 non-null    object
#  11  Profile          707 non-null    object
# dtypes: int64(10), object(2)
# memory usage: 66.4+ KB

# %%
data["Profile"].unique()
# Out:
# array(['UI/UX', 'Web Developer', 'DATA Scientist', 'Software Engineer',
#        'Database Administrator', 'Network Engineer', 'Tech Support'],
#       dtype=object)

# %%
data["Skill"].unique()
# Out:
# array(['Javascript', 'HTML/CSS', 'Photoshop', 'GitHub', 'Figma',
#        'Node.js', 'Angular', 'React', 'Python', 'R', 'Tensorflow',
#        'Deep Learning', 'Pytorch', 'Machine Learning', 'C/C++', 'Java',
#        'MYSQL', 'Oracle', 'Linux', 'Ansible', 'BASH/SHELL',
#        'Cisco Packet tracer', 'Wire Shark'], dtype=object)

# %%
#Metinsel ifadeleri sayısal değere çevirme
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
data['Skill'] = label_encoder.fit_transform(data['Skill'])
data['Profile'] = label_encoder.fit_transform(data['Profile'])

# %%
data
# Out:
#      DSA  DBMS  OS  CN  Mathmetics  Aptitute  Comm  Problem Solving  Creative  \
# 0     49    22  41  26           7        28    61                1         8
# 1     39    46  45  47           3        35    65                4        10
# 2     28    32  45  35          10        23    85                3        10
# 3     52    38  33  38          19        27    62                1         9
# 4     23    31  30  38          10        13    72                4         8
# ..   ...   ...  ..  ..         ...       ...   ...              ...       ...
# 702   17    32  18  11           7        40    60                2         6
# 703    7    22  25  33           8        29    71                3         5
# 704   35     5  13  20          17        45    55                3         5
# 705   16    28   6   7          18        33    67                3         4
# 706   18    12  10  28          22        31    55                5         3
#
#      Hackathons  Skill  Profile
# ...

# %%
df.describe()
# Out:
#               DSA        DBMS          OS          CN  Mathmetics    Aptitute  \
# count  707.000000  707.000000  707.000000  707.000000  707.000000  707.000000
# mean    60.981612   64.224894   64.495050   58.698727   49.946252   56.231966
# std     23.835685   26.251595   23.475825   24.828101   29.690518   23.870756
# min      5.000000    5.000000    5.000000    5.000000    0.000000   13.000000
# 25%     45.000000   41.000000   53.000000   38.500000   22.500000   35.000000
# 50%     67.000000   76.000000   73.000000   62.000000   48.000000   60.000000
# 75%     80.000000   85.000000   82.500000   80.000000   78.000000   77.000000
# max     99.000000  100.000000   95.000000  100.000000   99.000000   99.000000
#
#              Comm  Problem Solving    Creative  Hackathons       Skill  \
# count  707.000000       707.000000  707.000000  707.000000  707.000000
# mean    69.254597         5.471004    6.151344    3.100424   10.589816
# ...

# %%
#Korelasyon Grafiği Oluşturma
import matplotlib.pyplot as plt

import seaborn as sns
fig, ax = plt.subplots(figsize=(14,len(X.columns)))
sns.heatmap(X.corr(), annot = True,  ax = ax)
# Out:
# <Axes: >

# %%
#Histogram Grafiği Oluşturma
num_columns = data.shape[1]
fig, axs = plt.subplots(nrows=num_columns, ncols=1, figsize=(6, 3 * num_columns))

for i in range(num_columns):
    axs[i].hist(data.iloc[:, i], bins=100, alpha=0.7)
    axs[i].set_title(f'{data.columns[i]}')
    axs[i].set_xlabel('Değer Aralığı')
    axs[i].set_ylabel('Frekans')

plt.tight_layout()
plt.show()

# %%
#Kutu-Bıyık Grafiği Oluşturma
features =data.columns
n_rows = len(features)

fig, axes = plt.subplots(nrows=n_rows, ncols=1, figsize=(6, 3 * n_rows))

for i, feature in enumerate(features):
    sns.boxplot(x=data[feature], ax=axes[i])
    axes[i].set_title(f'Box Plot of {feature}')
plt.tight_layout()
plt.show()

# %%
# Hedef değişken ve bağımsız değişkenleri belirleme
X = df[['DSA', 'DBMS', 'OS', 'CN', 'Mathmetics', 'Aptitute', 'Comm', 'Problem Solving', 'Creative', 'Hackathons', 'Skill']]
y = df['Profile']

# Veriyi eğitim ve test setlerine bölelim
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Karar ağacı modelini oluşturma
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor(random_state=42)
model.fit(X_train, y_train)

# Test seti üzerinde tahmin yapma
y_pred = model.predict(X_test)

# Model performansını değerlendirme
print(model.score(X_train,y_train))
print(model.score(X_test,y_test))
# Out:
# 1.0
# 1.0

# %%
#  Öğrenciye meslek önermek için verileri girdik
new_data = {
    'DSA': [60],  #5-99
    'DBMS': [60], #5-100
    'OS': [85],   #5-95
    'CN': [80],   #5-100
    'Mathmetics':[90],  #0-99
    'Aptitute': [90],  #13-99
    'Comm': [60],      #40-90
    'Problem Solving': [7], #1-10
    'Creative': [8],  #2-10
    'Hackathons': [6], #0-10
    'Skill': [9]       #0-22
}

new_df = pd.DataFrame(new_data)

# Tahmin yapın
predicted_price = model.predict(new_df)
print(f"Önerilen Meslek: {predicted_price[0]}")
# Out:
# Önerilen Meslek: 3.0
